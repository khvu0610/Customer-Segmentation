# %%
# import libraries
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import calendar 
import datetime as dt  
# %matplotlib inline

# %%
# read in NewCustomerList sheet from file
new_customers = pd.read_excel('D:\OneDrive\Máy tính\KPMG_VI_New_raw_data_update_final.xlsx\KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='NewCustomerList', header=1)

# %%
new_customers
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#                      DOB                     job_title job_industry_category  \
# 0             1957-07-12               General Manager         Manufacturing
# 1             1970-03-22           Structural Engineer              Property
# 2    1974-08-28 00:00:00        Senior Cost Accountant    Financial Services
# 3             1979-01-28    Account Representative III         Manufacturing
# 4             1965-09-21             Financial Analyst    Financial Services
# ..                   ...                           ...                   ...
# 995           1959-10-07                     Paralegal    Financial Services
# 996           2001-10-17        Senior Sales Associate                Health
# 997           1954-10-05  Budget/Accounting Analyst IV    Financial Services
# 998           1952-12-17             Financial Advisor    Financial Services
# 999           1955-10-02           Staff Accountant IV              Property
#
#         wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0        Mass Customer                  N      Yes  ...    QLD  Australia
# 1        Mass Customer                  N       No  ...    NSW  Australia
# 2    Affluent Customer                  N       No  ...    VIC  Australia
# 3    Affluent Customer                  N      Yes  ...    QLD  Australia
# 4    Affluent Customer                  N       No  ...    NSW  Australia
# ..                 ...                ...      ...  ...    ...        ...
# 995  Affluent Customer                  N       No  ...    NSW  Australia
# 996      Mass Customer                  N       No  ...    NSW  Australia
# 997  Affluent Customer                  N      Yes  ...    QLD  Australia
# 998      Mass Customer                  N      Yes  ...    QLD  Australia
# 999      Mass Customer                  N      Yes  ...    NSW  Australia
#
#      property_valuation Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0                     6        0.56      0.7000     0.875000     0.743750
# 1                    11        0.89      0.8900     1.112500     0.945625
# 2                     5        1.01      1.0100     1.010000     1.010000
# 3                     1        0.87      1.0875     1.087500     1.087500
# 4                     9        0.52      0.5200     0.650000     0.650000
# ..                  ...         ...         ...          ...          ...
# 995                   7        0.79      0.7900     0.790000     0.790000
# 996                  10        0.76      0.7600     0.950000     0.807500
# 997                   2        0.85      1.0625     1.062500     1.062500
# 998                   2        1.09      1.3625     1.362500     1.158125
# 999                   9        0.47      0.5875     0.734375     0.624219
#
#      Unnamed: 20  Rank     Value
# 0              1     1  1.718750
# 1              1     1  1.718750
# 2              1     1  1.718750
# 3              4     4  1.703125
# 4              4     4  1.703125
# ..           ...   ...       ...
# 995          996   996  0.374000
# 996          997   997  0.357000
# 997          997   997  0.357000
# 998          997   997  0.357000
# 999         1000  1000  0.340000
#
# [1000 rows x 23 columns]

# %%
# check summary statistics
new_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    object
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   int64
#  16  Unnamed: 16                          1000 non-null   float64
#  17  Unnamed: 17                          1000 non-null   float64
#  18  Unnamed: 18                          1000 non-null   float64
#  19  Unnamed: 19                          1000 non-null   float64
#  20  Unnamed: 20                          1000 non-null   int64
#  21  Rank                                 1000 non-null   int64
#  22  Value                                1000 non-null   float64
# dtypes: float64(5), int64(6), object(12)
# memory usage: 179.8+ KB

# %%
# count missing values in each variable
new_customers.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
# calculate missing value percentage for each column
new_customers.isnull().mean() * 100
# Out:
# first_name                              0.0
# last_name                               2.9
# gender                                  0.0
# past_3_years_bike_related_purchases     0.0
# DOB                                     1.7
# job_title                              10.6
# job_industry_category                  16.5
# wealth_segment                          0.0
# deceased_indicator                      0.0
# owns_car                                0.0
# tenure                                  0.0
# address                                 0.0
# postcode                                0.0
# state                                   0.0
# country                                 0.0
# property_valuation                      0.0
# Unnamed: 16                             0.0
# Unnamed: 17                             0.0
# Unnamed: 18                             0.0
# Unnamed: 19                             0.0
# Unnamed: 20                             0.0
# Rank                                    0.0
# Value                                   0.0
# dtype: float64

# %%
# fill in the job_title,job_industry_category column with the mode value which is the most repeated value in the column
new_customers['job_title'] = new_customers['job_title'].fillna(new_customers['job_title'].mode()[0])
new_customers['job_industry_category'] = new_customers['job_industry_category'].fillna(new_customers['job_industry_category'].mode()[0])

# %%
# remove rows with null values in other columns
new_customers.dropna(axis=0,inplace=True)

# %%
# check results after removing null values
new_customers.isnull().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Unnamed: 16                            0
# Unnamed: 17                            0
# Unnamed: 18                            0
# Unnamed: 19                            0
# Unnamed: 20                            0
# Rank                                   0
# Value                                  0
# dtype: int64

# %%
# dropping U from gender
new_customers=new_customers[new_customers.gender!='U']

# %%
# amend column data types
new_customers['DOB'] = new_customers['DOB'].astype('datetime64[ns]')

# %%
# check information for the changes
new_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 954 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           954 non-null    object
#  1   last_name                            954 non-null    object
#  2   gender                               954 non-null    object
#  3   past_3_years_bike_related_purchases  954 non-null    int64
#  4   DOB                                  954 non-null    datetime64[ns]
#  5   job_title                            954 non-null    object
#  6   job_industry_category                954 non-null    object
#  7   wealth_segment                       954 non-null    object
#  8   deceased_indicator                   954 non-null    object
#  9   owns_car                             954 non-null    object
#  10  tenure                               954 non-null    int64
#  11  address                              954 non-null    object
#  12  postcode                             954 non-null    int64
#  13  state                                954 non-null    object
#  14  country                              954 non-null    object
#  15  property_valuation                   954 non-null    int64
#  16  Unnamed: 16                          954 non-null    float64
#  17  Unnamed: 17                          954 non-null    float64
#  18  Unnamed: 18                          954 non-null    float64
#  19  Unnamed: 19                          954 non-null    float64
#  20  Unnamed: 20                          954 non-null    int64
#  21  Rank                                 954 non-null    int64
#  22  Value                                954 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(6), object(11)
# memory usage: 178.9+ KB

# %%
# drop unknown columns, 16-20 columns
new_customers.drop(['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],axis=1,inplace=True)

# %%
# function converts given date to age
def from_dob_to_age(born):
    today = dt.date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
# apply function on the DOB column
new_customers['age']=new_customers['DOB'].apply(lambda x: from_dob_to_age(x))

# %%
# divide age group
Age_group = pd.cut(new_customers.age, bins = [20,30,50,70,92], labels= ['20-30','31-50','51-70','71-92'])
new_customers.insert(19, 'age_group', Age_group)

# %%
new_customers.to_csv(r"d:\OneDrive\Máy tính\Segmentation\new_customers.csv", index=False)
